# %%
import csv
import pandas as pd 
import numpy as np 


adjectives = pd.read_csv('C:/Users/nsw26/Desktop/Coding projects/domainsearch/adjectives.csv')
verbs = pd.read_csv('C:/Users/nsw26/Desktop/Coding projects/domainsearch/verbs.csv')


organized=pd.DataFrame()

organized['Adjectives']=adjectives
organized['Verbs']=verbs 
organized['Combined']=organized['Verbs']+organized['Adjectives']+".com"


organized.head()





#adjectivesList=[]
#verbsList = []
#for i in adjectives:
    #adjectivesList.append(i)
#for i in verbs:
    #verbsList.append(i)
#organized = pd.DataFrame([adjectivesList,verbsList],columns=['Adjectives','Verbs'])
#organized.head()
# Out:
#     Adjectives Verbs            Combined
# 0       abrupt    is        isabrupt.com
# 1       acidic   are       areacidic.com
# 2     adorable   has     hasadorable.com
# 3  adventurous   get  getadventurous.com
# 4   aggressive   see   seeaggressive.com
